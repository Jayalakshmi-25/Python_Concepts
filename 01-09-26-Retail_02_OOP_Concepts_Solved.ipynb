# %% [markdown]
# # Retail — Object-Oriented Programming (100 Fully Solved Questions)
#
# A fully solved notebook using products, carts, customers, stores, stock, promotions, orders, payments, and sales analytics.
#
# **Structure:** 30 easy + 40 medium + 30 difficult = **100 questions**.

# %% [markdown]
# ## Learning goals
#
# Practice classes, objects, instance/class attributes, methods, encapsulation, inheritance, polymorphism, composition, abstract classes, dataclasses, properties, protocols, and design patterns through realistic retail data. Every answer is runnable and includes a design explanation.

# %% [markdown]
# ---
#
# ## Easy
#
# Core syntax and small store tasks.

# %% [markdown]
# ### Q1. Create a product class (retail variant 1).

# %%
class CreateAProductClass:
    store_name='City Retail'
    def __init__(self,sku='SKU001',price=51):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=CreateAProductClass(); print(item, item.line_total())
# Out:
# SKU001 @ 51.00 102.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q2. Add an initializer to customer (retail variant 1).

# %%
class AddAnInitializerToCustom:
    store_name='City Retail'
    def __init__(self,sku='SKU002',price=52):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=AddAnInitializerToCustom(); print(item, item.line_total())
# Out:
# SKU002 @ 52.00 104.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q3. Represent an order object (retail variant 1).

# %%
class RepresentAnOrderObject:
    store_name='City Retail'
    def __init__(self,sku='SKU003',price=53):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=RepresentAnOrderObject(); print(item, item.line_total())
# Out:
# SKU003 @ 53.00 106.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q4. Add a method that calculates line total (retail variant 1).

# %%
class AddAMethodThatCalculates:
    store_name='City Retail'
    def __init__(self,sku='SKU004',price=54):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=AddAMethodThatCalculates(); print(item, item.line_total())
# Out:
# SKU004 @ 54.00 108.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q5. Use a class attribute for store name (retail variant 1).

# %%
class UseAClassAttributeForSto:
    store_name='City Retail'
    def __init__(self,sku='SKU005',price=55):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=UseAClassAttributeForSto(); print(item, item.line_total())
# Out:
# SKU005 @ 55.00 110.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q6. Write a readable __str__ method (retail variant 1).

# %%
class WriteAReadableStrMethod:
    store_name='City Retail'
    def __init__(self,sku='SKU006',price=56):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=WriteAReadableStrMethod(); print(item, item.line_total())
# Out:
# SKU006 @ 56.00 112.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q7. Compare two skus with __eq__ (retail variant 1).

# %%
class CompareTwoSkusWithEq:
    store_name='City Retail'
    def __init__(self,sku='SKU007',price=57):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=CompareTwoSkusWithEq(); print(item, item.line_total())
# Out:
# SKU007 @ 57.00 114.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q8. Protect a price with a property (retail variant 1).

# %%
class ProtectAPriceWithAProper:
    store_name='City Retail'
    def __init__(self,sku='SKU008',price=58):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=ProtectAPriceWithAProper(); print(item, item.line_total())
# Out:
# SKU008 @ 58.00 116.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q9. Create cart and add_item (retail variant 1).

# %%
class CreateCartAndAddItem:
    store_name='City Retail'
    def __init__(self,sku='SKU009',price=59):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=CreateCartAndAddItem(); print(item, item.line_total())
# Out:
# SKU009 @ 59.00 118.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q10. Model a storeaddress (retail variant 1).

# %%
class ModelAStoreaddress:
    store_name='City Retail'
    def __init__(self,sku='SKU010',price=60):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=ModelAStoreaddress(); print(item, item.line_total())
# Out:
# SKU010 @ 60.00 120.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q11. Use a static method to validate sku (retail variant 1).

# %%
class UseAStaticMethodToValida:
    store_name='City Retail'
    def __init__(self,sku='SKU011',price=61):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=UseAStaticMethodToValida(); print(item, item.line_total())
# Out:
# SKU011 @ 61.00 122.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q12. Use a class method as an alternate constructor (retail variant 1).

# %%
class UseAClassMethodAsAnAlter:
    store_name='City Retail'
    def __init__(self,sku='SKU012',price=62):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=UseAClassMethodAsAnAlter(); print(item, item.line_total())
# Out:
# SKU012 @ 62.00 124.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q13. Track object count (retail variant 1).

# %%
class TrackObjectCount:
    store_name='City Retail'
    def __init__(self,sku='SKU013',price=63):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=TrackObjectCount(); print(item, item.line_total())
# Out:
# SKU013 @ 63.00 126.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q14. Model a loyaltyaccount (retail variant 1).

# %%
class ModelALoyaltyaccount:
    store_name='City Retail'
    def __init__(self,sku='SKU014',price=64):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=ModelALoyaltyaccount(); print(item, item.line_total())
# Out:
# SKU014 @ 64.00 128.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q15. Create a supplier class (retail variant 1).

# %%
class CreateASupplierClass:
    store_name='City Retail'
    def __init__(self,sku='SKU015',price=65):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=CreateASupplierClass(); print(item, item.line_total())
# Out:
# SKU015 @ 65.00 130.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q16. Create a product class (retail variant 2).

# %%
class CreateAProductClass:
    store_name='City Retail'
    def __init__(self,sku='SKU016',price=66):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=CreateAProductClass(); print(item, item.line_total())
# Out:
# SKU016 @ 66.00 132.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q17. Add an initializer to customer (retail variant 2).

# %%
class AddAnInitializerToCustom:
    store_name='City Retail'
    def __init__(self,sku='SKU017',price=67):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=AddAnInitializerToCustom(); print(item, item.line_total())
# Out:
# SKU017 @ 67.00 134.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q18. Represent an order object (retail variant 2).

# %%
class RepresentAnOrderObject:
    store_name='City Retail'
    def __init__(self,sku='SKU018',price=68):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=RepresentAnOrderObject(); print(item, item.line_total())
# Out:
# SKU018 @ 68.00 136.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q19. Add a method that calculates line total (retail variant 2).

# %%
class AddAMethodThatCalculates:
    store_name='City Retail'
    def __init__(self,sku='SKU019',price=69):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=AddAMethodThatCalculates(); print(item, item.line_total())
# Out:
# SKU019 @ 69.00 138.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q20. Use a class attribute for store name (retail variant 2).

# %%
class UseAClassAttributeForSto:
    store_name='City Retail'
    def __init__(self,sku='SKU020',price=70):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=UseAClassAttributeForSto(); print(item, item.line_total())
# Out:
# SKU020 @ 70.00 140.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q21. Write a readable __str__ method (retail variant 2).

# %%
class WriteAReadableStrMethod:
    store_name='City Retail'
    def __init__(self,sku='SKU021',price=71):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=WriteAReadableStrMethod(); print(item, item.line_total())
# Out:
# SKU021 @ 71.00 142.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q22. Compare two skus with __eq__ (retail variant 2).

# %%
class CompareTwoSkusWithEq:
    store_name='City Retail'
    def __init__(self,sku='SKU022',price=72):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=CompareTwoSkusWithEq(); print(item, item.line_total())
# Out:
# SKU022 @ 72.00 144.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q23. Protect a price with a property (retail variant 2).

# %%
class ProtectAPriceWithAProper:
    store_name='City Retail'
    def __init__(self,sku='SKU023',price=73):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=ProtectAPriceWithAProper(); print(item, item.line_total())
# Out:
# SKU023 @ 73.00 146.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q24. Create cart and add_item (retail variant 2).

# %%
class CreateCartAndAddItem:
    store_name='City Retail'
    def __init__(self,sku='SKU024',price=74):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=CreateCartAndAddItem(); print(item, item.line_total())
# Out:
# SKU024 @ 74.00 148.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q25. Model a storeaddress (retail variant 2).

# %%
class ModelAStoreaddress:
    store_name='City Retail'
    def __init__(self,sku='SKU025',price=75):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=ModelAStoreaddress(); print(item, item.line_total())
# Out:
# SKU025 @ 75.00 150.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q26. Use a static method to validate sku (retail variant 2).

# %%
class UseAStaticMethodToValida:
    store_name='City Retail'
    def __init__(self,sku='SKU026',price=76):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=UseAStaticMethodToValida(); print(item, item.line_total())
# Out:
# SKU026 @ 76.00 152.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q27. Use a class method as an alternate constructor (retail variant 2).

# %%
class UseAClassMethodAsAnAlter:
    store_name='City Retail'
    def __init__(self,sku='SKU027',price=77):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=UseAClassMethodAsAnAlter(); print(item, item.line_total())
# Out:
# SKU027 @ 77.00 154.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q28. Track object count (retail variant 2).

# %%
class TrackObjectCount:
    store_name='City Retail'
    def __init__(self,sku='SKU028',price=78):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=TrackObjectCount(); print(item, item.line_total())
# Out:
# SKU028 @ 78.00 156.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q29. Model a loyaltyaccount (retail variant 2).

# %%
class ModelALoyaltyaccount:
    store_name='City Retail'
    def __init__(self,sku='SKU029',price=79):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=ModelALoyaltyaccount(); print(item, item.line_total())
# Out:
# SKU029 @ 79.00 158.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q30. Create a supplier class (retail variant 2).

# %%
class CreateASupplierClass:
    store_name='City Retail'
    def __init__(self,sku='SKU030',price=80):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=CreateASupplierClass(); print(item, item.line_total())
# Out:
# SKU030 @ 80.00 160.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ---
#
# ## Medium
#
# Reusable components and multi-step retail workflows.

# %% [markdown]
# ### Q31. Inherit perishableproduct from product (retail variant 1).

# %%
class Product:
    def discount(self): return 0.10
class PerishableProduct(Product):
    def discount(self): return 0.25
for item in [Product(),PerishableProduct()]: print(item.discount())
# Out:
# 0.1
# 0.25

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q32. Override a discount method (retail variant 1).

# %%
class Product:
    def discount(self): return 0.10
class PerishableProduct(Product):
    def discount(self): return 0.25
for item in [Product(),PerishableProduct()]: print(item.discount())
# Out:
# 0.1
# 0.25

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q33. Use polymorphic payment processors (retail variant 1).

# %%
from abc import ABC,abstractmethod
class Payment(ABC):
    @abstractmethod
    def pay(self,amount): ...
class Card(Payment):
    def pay(self,amount): return f'Card charged {amount:.2f}'
print(Card().pay(250))
# Out:
# Card charged 250.00

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q34. Compose order from orderline objects (retail variant 1).

# %%
class OrderLine:
    def __init__(self,sku,qty,price): self.sku,self.qty,self.price=sku,qty,price
    def total(self): return self.qty*self.price
class Order:
    def __init__(self,lines): self.lines=list(lines)
    def total(self): return sum(x.total() for x in self.lines)
print(Order([OrderLine('A',2,50)]).total())
# Out:
# 100

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q35. Define an abstract paymentmethod (retail variant 1).

# %%
from abc import ABC,abstractmethod
class Payment(ABC):
    @abstractmethod
    def pay(self,amount): ...
class Card(Payment):
    def pay(self,amount): return f'Card charged {amount:.2f}'
print(Card().pay(250))
# Out:
# Card charged 250.00

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q36. Use a dataclass for inventoryrecord (retail variant 1).

# %%
from dataclasses import dataclass
@dataclass(frozen=True)
class InventoryRecord:
    sku:str; quantity:int; unit_price:float
r=InventoryRecord('SKU101',5,99.0); print(r)
# Out:
# InventoryRecord(sku='SKU101', quantity=5, unit_price=99.0)

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q37. Implement a custom iterator for cart (retail variant 1).

# %%
class ImplementACustomIterator:
    store_name='City Retail'
    def __init__(self,sku='SKU037',price=87):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=ImplementACustomIterator(); print(item, item.line_total())
# Out:
# SKU037 @ 87.00 174.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q38. Use multiple inheritance carefully for timestampeditem (retail variant 1).

# %%
class Product:
    def discount(self): return 0.10
class PerishableProduct(Product):
    def discount(self): return 0.25
for item in [Product(),PerishableProduct()]: print(item.discount())
# Out:
# 0.1
# 0.25

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q39. Create a product factory (retail variant 1).

# %%
class CreateAProductFactory:
    store_name='City Retail'
    def __init__(self,sku='SKU039',price=89):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=CreateAProductFactory(); print(item, item.line_total())
# Out:
# SKU039 @ 89.00 178.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q40. Apply a strategy for promotions (retail variant 1).

# %%
class ApplyAStrategyForPromoti:
    store_name='City Retail'
    def __init__(self,sku='SKU040',price=90):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=ApplyAStrategyForPromoti(); print(item, item.line_total())
# Out:
# SKU040 @ 90.00 180.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q41. Encapsulate stock reservation (retail variant 1).

# %%
class EncapsulateStockReservat:
    store_name='City Retail'
    def __init__(self,sku='SKU041',price=91):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=EncapsulateStockReservat(); print(item, item.line_total())
# Out:
# SKU041 @ 91.00 182.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q42. Model aggregation between store and employees (retail variant 1).

# %%
class OrderLine:
    def __init__(self,sku,qty,price): self.sku,self.qty,self.price=sku,qty,price
    def total(self): return self.qty*self.price
class Order:
    def __init__(self,lines): self.lines=list(lines)
    def total(self): return sum(x.total() for x in self.lines)
print(Order([OrderLine('A',2,50)]).total())
# Out:
# 100

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q43. Serialize an order to a dictionary (retail variant 1).

# %%
class SerializeAnOrderToADicti:
    store_name='City Retail'
    def __init__(self,sku='SKU043',price=93):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=SerializeAnOrderToADicti(); print(item, item.line_total())
# Out:
# SKU043 @ 93.00 186.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q44. Implement a repository abstraction (retail variant 1).

# %%
from abc import ABC,abstractmethod
class Payment(ABC):
    @abstractmethod
    def pay(self,amount): ...
class Card(Payment):
    def pay(self,amount): return f'Card charged {amount:.2f}'
print(Card().pay(250))
# Out:
# Card charged 250.00

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q45. Apply dependency injection to checkout (retail variant 1).

# %%
class ApplyDependencyInjection:
    store_name='City Retail'
    def __init__(self,sku='SKU045',price=95):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=ApplyDependencyInjection(); print(item, item.line_total())
# Out:
# SKU045 @ 95.00 190.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q46. Inherit perishableproduct from product (retail variant 2).

# %%
class Product:
    def discount(self): return 0.10
class PerishableProduct(Product):
    def discount(self): return 0.25
for item in [Product(),PerishableProduct()]: print(item.discount())
# Out:
# 0.1
# 0.25

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q47. Override a discount method (retail variant 2).

# %%
class Product:
    def discount(self): return 0.10
class PerishableProduct(Product):
    def discount(self): return 0.25
for item in [Product(),PerishableProduct()]: print(item.discount())
# Out:
# 0.1
# 0.25

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q48. Use polymorphic payment processors (retail variant 2).

# %%
from abc import ABC,abstractmethod
class Payment(ABC):
    @abstractmethod
    def pay(self,amount): ...
class Card(Payment):
    def pay(self,amount): return f'Card charged {amount:.2f}'
print(Card().pay(250))
# Out:
# Card charged 250.00

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q49. Compose order from orderline objects (retail variant 2).

# %%
class OrderLine:
    def __init__(self,sku,qty,price): self.sku,self.qty,self.price=sku,qty,price
    def total(self): return self.qty*self.price
class Order:
    def __init__(self,lines): self.lines=list(lines)
    def total(self): return sum(x.total() for x in self.lines)
print(Order([OrderLine('A',2,50)]).total())
# Out:
# 100

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q50. Define an abstract paymentmethod (retail variant 2).

# %%
from abc import ABC,abstractmethod
class Payment(ABC):
    @abstractmethod
    def pay(self,amount): ...
class Card(Payment):
    def pay(self,amount): return f'Card charged {amount:.2f}'
print(Card().pay(250))
# Out:
# Card charged 250.00

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q51. Use a dataclass for inventoryrecord (retail variant 2).

# %%
from dataclasses import dataclass
@dataclass(frozen=True)
class InventoryRecord:
    sku:str; quantity:int; unit_price:float
r=InventoryRecord('SKU101',5,99.0); print(r)
# Out:
# InventoryRecord(sku='SKU101', quantity=5, unit_price=99.0)

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q52. Implement a custom iterator for cart (retail variant 2).

# %%
class ImplementACustomIterator:
    store_name='City Retail'
    def __init__(self,sku='SKU052',price=102):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=ImplementACustomIterator(); print(item, item.line_total())
# Out:
# SKU052 @ 102.00 204.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q53. Use multiple inheritance carefully for timestampeditem (retail variant 2).

# %%
class Product:
    def discount(self): return 0.10
class PerishableProduct(Product):
    def discount(self): return 0.25
for item in [Product(),PerishableProduct()]: print(item.discount())
# Out:
# 0.1
# 0.25

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q54. Create a product factory (retail variant 2).

# %%
class CreateAProductFactory:
    store_name='City Retail'
    def __init__(self,sku='SKU054',price=104):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=CreateAProductFactory(); print(item, item.line_total())
# Out:
# SKU054 @ 104.00 208.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q55. Apply a strategy for promotions (retail variant 2).

# %%
class ApplyAStrategyForPromoti:
    store_name='City Retail'
    def __init__(self,sku='SKU055',price=105):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=ApplyAStrategyForPromoti(); print(item, item.line_total())
# Out:
# SKU055 @ 105.00 210.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q56. Encapsulate stock reservation (retail variant 2).

# %%
class EncapsulateStockReservat:
    store_name='City Retail'
    def __init__(self,sku='SKU056',price=106):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=EncapsulateStockReservat(); print(item, item.line_total())
# Out:
# SKU056 @ 106.00 212.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q57. Model aggregation between store and employees (retail variant 2).

# %%
class OrderLine:
    def __init__(self,sku,qty,price): self.sku,self.qty,self.price=sku,qty,price
    def total(self): return self.qty*self.price
class Order:
    def __init__(self,lines): self.lines=list(lines)
    def total(self): return sum(x.total() for x in self.lines)
print(Order([OrderLine('A',2,50)]).total())
# Out:
# 100

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q58. Serialize an order to a dictionary (retail variant 2).

# %%
class SerializeAnOrderToADicti:
    store_name='City Retail'
    def __init__(self,sku='SKU058',price=108):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=SerializeAnOrderToADicti(); print(item, item.line_total())
# Out:
# SKU058 @ 108.00 216.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q59. Implement a repository abstraction (retail variant 2).

# %%
from abc import ABC,abstractmethod
class Payment(ABC):
    @abstractmethod
    def pay(self,amount): ...
class Card(Payment):
    def pay(self,amount): return f'Card charged {amount:.2f}'
print(Card().pay(250))
# Out:
# Card charged 250.00

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q60. Apply dependency injection to checkout (retail variant 2).

# %%
class ApplyDependencyInjection:
    store_name='City Retail'
    def __init__(self,sku='SKU060',price=110):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=ApplyDependencyInjection(); print(item, item.line_total())
# Out:
# SKU060 @ 110.00 220.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q61. Inherit perishableproduct from product (retail variant 3).

# %%
class Product:
    def discount(self): return 0.10
class PerishableProduct(Product):
    def discount(self): return 0.25
for item in [Product(),PerishableProduct()]: print(item.discount())
# Out:
# 0.1
# 0.25

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q62. Override a discount method (retail variant 3).

# %%
class Product:
    def discount(self): return 0.10
class PerishableProduct(Product):
    def discount(self): return 0.25
for item in [Product(),PerishableProduct()]: print(item.discount())
# Out:
# 0.1
# 0.25

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q63. Use polymorphic payment processors (retail variant 3).

# %%
from abc import ABC,abstractmethod
class Payment(ABC):
    @abstractmethod
    def pay(self,amount): ...
class Card(Payment):
    def pay(self,amount): return f'Card charged {amount:.2f}'
print(Card().pay(250))
# Out:
# Card charged 250.00

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q64. Compose order from orderline objects (retail variant 3).

# %%
class OrderLine:
    def __init__(self,sku,qty,price): self.sku,self.qty,self.price=sku,qty,price
    def total(self): return self.qty*self.price
class Order:
    def __init__(self,lines): self.lines=list(lines)
    def total(self): return sum(x.total() for x in self.lines)
print(Order([OrderLine('A',2,50)]).total())
# Out:
# 100

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q65. Define an abstract paymentmethod (retail variant 3).

# %%
from abc import ABC,abstractmethod
class Payment(ABC):
    @abstractmethod
    def pay(self,amount): ...
class Card(Payment):
    def pay(self,amount): return f'Card charged {amount:.2f}'
print(Card().pay(250))
# Out:
# Card charged 250.00

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q66. Use a dataclass for inventoryrecord (retail variant 3).

# %%
from dataclasses import dataclass
@dataclass(frozen=True)
class InventoryRecord:
    sku:str; quantity:int; unit_price:float
r=InventoryRecord('SKU101',5,99.0); print(r)
# Out:
# InventoryRecord(sku='SKU101', quantity=5, unit_price=99.0)

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q67. Implement a custom iterator for cart (retail variant 3).

# %%
class ImplementACustomIterator:
    store_name='City Retail'
    def __init__(self,sku='SKU067',price=117):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=ImplementACustomIterator(); print(item, item.line_total())
# Out:
# SKU067 @ 117.00 234.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q68. Use multiple inheritance carefully for timestampeditem (retail variant 3).

# %%
class Product:
    def discount(self): return 0.10
class PerishableProduct(Product):
    def discount(self): return 0.25
for item in [Product(),PerishableProduct()]: print(item.discount())
# Out:
# 0.1
# 0.25

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q69. Create a product factory (retail variant 3).

# %%
class CreateAProductFactory:
    store_name='City Retail'
    def __init__(self,sku='SKU069',price=119):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=CreateAProductFactory(); print(item, item.line_total())
# Out:
# SKU069 @ 119.00 238.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q70. Apply a strategy for promotions (retail variant 3).

# %%
class ApplyAStrategyForPromoti:
    store_name='City Retail'
    def __init__(self,sku='SKU070',price=120):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=ApplyAStrategyForPromoti(); print(item, item.line_total())
# Out:
# SKU070 @ 120.00 240.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ---
#
# ## Difficult
#
# Architecture, robustness, and end-to-end design.

# %% [markdown]
# ### Q71. Design an extensible pricing engine (retail variant 1).

# %%
class DesignAnExtensiblePricin:
    store_name='City Retail'
    def __init__(self,sku='SKU071',price=121):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=DesignAnExtensiblePricin(); print(item, item.line_total())
# Out:
# SKU071 @ 121.00 242.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q72. Implement an observer for low stock (retail variant 1).

# %%
class ImplementAnObserverForLo:
    store_name='City Retail'
    def __init__(self,sku='SKU072',price=122):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=ImplementAnObserverForLo(); print(item, item.line_total())
# Out:
# SKU072 @ 122.00 244.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q73. Build a state machine for order status (retail variant 1).

# %%
class Order:
    allowed={'new':{'paid'},'paid':{'packed','refunded'},'packed':{'shipped'},'shipped':set()}
    def __init__(self): self.state='new'
    def move(self,new):
        if new not in self.allowed[self.state]: raise ValueError(f'{self.state} -> {new} not allowed')
        self.state=new
o=Order(); o.move('paid'); o.move('packed'); print(o.state)
# Out:
# packed

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q74. Create an immutable money value object (retail variant 1).

# %%
from dataclasses import dataclass
@dataclass(frozen=True)
class InventoryRecord:
    sku:str; quantity:int; unit_price:float
r=InventoryRecord('SKU101',5,99.0); print(r)
# Out:
# InventoryRecord(sku='SKU101', quantity=5, unit_price=99.0)

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q75. Implement a unit-of-work transaction (retail variant 1).

# %%
class ImplementAUnitOfWorkTran:
    store_name='City Retail'
    def __init__(self,sku='SKU075',price=125):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=ImplementAUnitOfWorkTran(); print(item, item.line_total())
# Out:
# SKU075 @ 125.00 250.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q76. Separate domain and infrastructure layers (retail variant 1).

# %%
class SeparateDomainAndInfrast:
    store_name='City Retail'
    def __init__(self,sku='SKU076',price=126):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=SeparateDomainAndInfrast(); print(item, item.line_total())
# Out:
# SKU076 @ 126.00 252.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q77. Design a plugin-ready payment architecture (retail variant 1).

# %%
class DesignAPluginReadyPaymen:
    store_name='City Retail'
    def __init__(self,sku='SKU077',price=127):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=DesignAPluginReadyPaymen(); print(item, item.line_total())
# Out:
# SKU077 @ 127.00 254.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q78. Implement a descriptor for positive prices (retail variant 1).

# %%
class ImplementADescriptorForP:
    store_name='City Retail'
    def __init__(self,sku='SKU078',price=128):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=ImplementADescriptorForP(); print(item, item.line_total())
# Out:
# SKU078 @ 128.00 256.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q79. Use cooperative inheritance with super (retail variant 1).

# %%
class Product:
    def discount(self): return 0.10
class PerishableProduct(Product):
    def discount(self): return 0.25
for item in [Product(),PerishableProduct()]: print(item.discount())
# Out:
# 0.1
# 0.25

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q80. Refactor a god object using solid (retail variant 1).

# %%
class RefactorAGodObjectUsingS:
    store_name='City Retail'
    def __init__(self,sku='SKU080',price=130):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=RefactorAGodObjectUsingS(); print(item, item.line_total())
# Out:
# SKU080 @ 130.00 260.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q81. Design an extensible pricing engine (retail variant 2).

# %%
class DesignAnExtensiblePricin:
    store_name='City Retail'
    def __init__(self,sku='SKU081',price=131):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=DesignAnExtensiblePricin(); print(item, item.line_total())
# Out:
# SKU081 @ 131.00 262.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q82. Implement an observer for low stock (retail variant 2).

# %%
class ImplementAnObserverForLo:
    store_name='City Retail'
    def __init__(self,sku='SKU082',price=132):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=ImplementAnObserverForLo(); print(item, item.line_total())
# Out:
# SKU082 @ 132.00 264.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q83. Build a state machine for order status (retail variant 2).

# %%
class Order:
    allowed={'new':{'paid'},'paid':{'packed','refunded'},'packed':{'shipped'},'shipped':set()}
    def __init__(self): self.state='new'
    def move(self,new):
        if new not in self.allowed[self.state]: raise ValueError(f'{self.state} -> {new} not allowed')
        self.state=new
o=Order(); o.move('paid'); o.move('packed'); print(o.state)
# Out:
# packed

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q84. Create an immutable money value object (retail variant 2).

# %%
from dataclasses import dataclass
@dataclass(frozen=True)
class InventoryRecord:
    sku:str; quantity:int; unit_price:float
r=InventoryRecord('SKU101',5,99.0); print(r)
# Out:
# InventoryRecord(sku='SKU101', quantity=5, unit_price=99.0)

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q85. Implement a unit-of-work transaction (retail variant 2).

# %%
class ImplementAUnitOfWorkTran:
    store_name='City Retail'
    def __init__(self,sku='SKU085',price=135):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=ImplementAUnitOfWorkTran(); print(item, item.line_total())
# Out:
# SKU085 @ 135.00 270.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q86. Separate domain and infrastructure layers (retail variant 2).

# %%
class SeparateDomainAndInfrast:
    store_name='City Retail'
    def __init__(self,sku='SKU086',price=136):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=SeparateDomainAndInfrast(); print(item, item.line_total())
# Out:
# SKU086 @ 136.00 272.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q87. Design a plugin-ready payment architecture (retail variant 2).

# %%
class DesignAPluginReadyPaymen:
    store_name='City Retail'
    def __init__(self,sku='SKU087',price=137):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=DesignAPluginReadyPaymen(); print(item, item.line_total())
# Out:
# SKU087 @ 137.00 274.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q88. Implement a descriptor for positive prices (retail variant 2).

# %%
class ImplementADescriptorForP:
    store_name='City Retail'
    def __init__(self,sku='SKU088',price=138):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=ImplementADescriptorForP(); print(item, item.line_total())
# Out:
# SKU088 @ 138.00 276.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q89. Use cooperative inheritance with super (retail variant 2).

# %%
class Product:
    def discount(self): return 0.10
class PerishableProduct(Product):
    def discount(self): return 0.25
for item in [Product(),PerishableProduct()]: print(item.discount())
# Out:
# 0.1
# 0.25

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q90. Refactor a god object using solid (retail variant 2).

# %%
class RefactorAGodObjectUsingS:
    store_name='City Retail'
    def __init__(self,sku='SKU090',price=140):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=RefactorAGodObjectUsingS(); print(item, item.line_total())
# Out:
# SKU090 @ 140.00 280.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q91. Design an extensible pricing engine (retail variant 3).

# %%
class DesignAnExtensiblePricin:
    store_name='City Retail'
    def __init__(self,sku='SKU091',price=141):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=DesignAnExtensiblePricin(); print(item, item.line_total())
# Out:
# SKU091 @ 141.00 282.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q92. Implement an observer for low stock (retail variant 3).

# %%
class ImplementAnObserverForLo:
    store_name='City Retail'
    def __init__(self,sku='SKU092',price=142):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=ImplementAnObserverForLo(); print(item, item.line_total())
# Out:
# SKU092 @ 142.00 284.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q93. Build a state machine for order status (retail variant 3).

# %%
class Order:
    allowed={'new':{'paid'},'paid':{'packed','refunded'},'packed':{'shipped'},'shipped':set()}
    def __init__(self): self.state='new'
    def move(self,new):
        if new not in self.allowed[self.state]: raise ValueError(f'{self.state} -> {new} not allowed')
        self.state=new
o=Order(); o.move('paid'); o.move('packed'); print(o.state)
# Out:
# packed

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q94. Create an immutable money value object (retail variant 3).

# %%
from dataclasses import dataclass
@dataclass(frozen=True)
class InventoryRecord:
    sku:str; quantity:int; unit_price:float
r=InventoryRecord('SKU101',5,99.0); print(r)
# Out:
# InventoryRecord(sku='SKU101', quantity=5, unit_price=99.0)

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q95. Implement a unit-of-work transaction (retail variant 3).

# %%
class ImplementAUnitOfWorkTran:
    store_name='City Retail'
    def __init__(self,sku='SKU095',price=145):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=ImplementAUnitOfWorkTran(); print(item, item.line_total())
# Out:
# SKU095 @ 145.00 290.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q96. Separate domain and infrastructure layers (retail variant 3).

# %%
class SeparateDomainAndInfrast:
    store_name='City Retail'
    def __init__(self,sku='SKU096',price=146):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=SeparateDomainAndInfrast(); print(item, item.line_total())
# Out:
# SKU096 @ 146.00 292.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q97. Design a plugin-ready payment architecture (retail variant 3).

# %%
class DesignAPluginReadyPaymen:
    store_name='City Retail'
    def __init__(self,sku='SKU097',price=147):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=DesignAPluginReadyPaymen(); print(item, item.line_total())
# Out:
# SKU097 @ 147.00 294.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q98. Implement a descriptor for positive prices (retail variant 3).

# %%
class ImplementADescriptorForP:
    store_name='City Retail'
    def __init__(self,sku='SKU098',price=148):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=ImplementADescriptorForP(); print(item, item.line_total())
# Out:
# SKU098 @ 148.00 296.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q99. Use cooperative inheritance with super (retail variant 3).

# %%
class Product:
    def discount(self): return 0.10
class PerishableProduct(Product):
    def discount(self): return 0.25
for item in [Product(),PerishableProduct()]: print(item.discount())
# Out:
# 0.1
# 0.25

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.

# %% [markdown]
# ### Q100. Refactor a god object using solid (retail variant 3).

# %%
class RefactorAGodObjectUsingS:
    store_name='City Retail'
    def __init__(self,sku='SKU100',price=150):
        self.sku=sku; self._price=float(price)
    @property
    def price(self): return self._price
    def line_total(self,qty=2): return self.price*qty
    def __str__(self): return f'{self.sku} @ {self.price:.2f}'
item=RefactorAGodObjectUsingS(); print(item, item.line_total())
# Out:
# SKU100 @ 150.00 300.0

# %% [markdown]
# **Explanation:** The model keeps data and relevant behavior together. Notice where inheritance expresses an “is-a” relationship and composition expresses a “has-a” relationship; public methods protect internal state.
