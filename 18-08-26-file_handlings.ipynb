# %%
pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 382.9/382.9 kB 7.2 MB/s eta 0:00:00
# ...

# %%
root folder /*
inside folder /*/*
level2 , level3: /*/*/*

# %%
import glob
glob.glob("/content/*/*.csv")
# Out:
# ['/content/sample_data/california_housing_test.csv',
#  '/content/sample_data/california_housing_train.csv',
#  '/content/sample_data/mnist_test.csv',
#  '/content/sample_data/mnist_train_small.csv']

# %%
# Install:
# pip install pypdf

from pypdf import PdfReader

reader = PdfReader("/content/Amit_DE_Resume.pdf")

print("Total pages:", len(reader.pages))

for page_number, page in enumerate(reader.pages, start=1):
    text = page.extract_text()

    print(f"\n--- Page {page_number} ---")
    print(text)
# Out:
# Total pages: 2
#
# --- Page 1 ---
# 8 2 7 1 6 6 2 7 4 9 A m i t k u m a r a n a l y t i c @ g m a i l . c o m B e n g a l u r u , I n d i a
# P R O F I L E  S U M M A R Y
# A z u r e  D a t a  E n g i n e e r  w i t h  2 +  y e a r s  o f  r e l e v a n t  e x p e r i e n c e  i n  d e s i g n i n g ,  d e v e l o p i n g ,  a n d  o p t i m i z i n g  s c a l a b l e  c l o u d - b a s e d
# d a t a  s o l u t i o n s  u s i n g  M i c r o s o f t  A z u r e  t e c h n o l o g i e s .  S k i l l e d  i n  A z u r e  D a t a  F a c t o r y  ( A D F ) ,  A z u r e  D a t a b r i c k s ,  A D L S  G e n 2 ,
# M i c r o s o f t  F a b r i c ,  P y S p a r k ,  P y t h o n ,  a n d  S Q L  w i t h  s t r o n g  e x p e r t i s e  i n  b u i l d i n g  E T L / E L T  p i p e l i n e s ,  M e d a l l i o n  A r c h i t e c t u r e ,
# ...

# %%
### read all pdf files from a folder
### extract text from each pdf file
### print pdf file name, length of text and number of words

# %%
import glob
file_names=[i for i in glob.glob('/content/*.pdf')]

# %%
len(file_names)
# Out:
# 93

# %%
for i in file_names[0:10]:
  reader = PdfReader(i)
  #print("Total pages:", i,len(reader.pages))
  pdf_text=""
  total_length=0
  for page_number,page in enumerate(reader.pages,start=1):
    text=page.extract_text()
    pdf_text=pdf_text+text
    total_length=total_length+len(pdf_text)
  print(i,len(pdf_text),len(pdf_text.split()),len(reader.pages))
print("average length",total_length/len(file_names[0:10]))
# for page_number, page in enumerate(reader.pages, start=1):
#     text = page.extract_text()

#     print(f"\n--- Page {page_number} ---")
#     print(text)
# Out:
# /content/omkareshwari_Resume(1)-1.pdf 3712 493 1
# /content/Swathi _Resume.pdf 0 0 1
# /content/keerthana_resume-1 (1) (1).pdf 6084 853 2
# /content/Akhil_Dharimisetty_GenAI_Resume (2)-1.pdf 5609 750 2
# /content/Siripireddy Indira Reddy (DS).pdf 4982 649 2
# /content/Chakradhar_Devops_Resume.pdf 14760 6678 2
# /content/Varun__.pdf 5670 664 2
# /content/Arunkumar_AWS_DevOps_Resume.pdf 8769 1177 2
# /content/Girija_Fabric_resume (3).pdf 9480 1278 2
# /content/Vikitha_Marthula_Data Engineer_Resume.pdf 5022 659 2
# average length 805.6

# %%
# !pip install pdfplumber
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 28.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 52.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 23.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
# ...

# %%
import pdfplumber

with pdfplumber.open("/content/Adarsh_DS.pdf.pdf") as pdf:

    print("Total pages:", len(pdf.pages))

    for page_number, page in enumerate(pdf.pages, start=1):

        text = page.extract_text()

        print(f"\n--- Page {page_number} ---")
        print(text)
# Out:
# Total pages: 2
#
# --- Page 1 ---
# G ADARSH KUMAR REDDY
# DataScientist | 2.7 YearsExperience | ML | Generative AI | Agent AI | NLP
# gadarshkumarreddy2001@gmail.com 8688637288 Bangalore, India
# Data Scientist with 2.7 years of experience in Generative AI, Agentic AI workflows, and RAG systems, delivering
# enterprise-scale solutions across banking, compliance, and customer support. Designed document intelligence
# platforms ensuring GDPR compliance and reducing manual validation by 65% Built enterprise- grade chatbots
# for IT helpdesk, customer support, and marketing, integrating LLMs with knowledge bases for contextual
# accuracy. Developed ML models for churn prediction, fraud detection, and loyalty analysis, alongside analytics
# dashboards that enabled actionable business insights.
# Experience
# DataScientist | AIML Labs Pvt Ltd from 2024 Jan to Present
# Designed and deployed Agentic AI workflows using LangGraph and RAG-based architectures for financial
# ...

# %%
# !pip install pymupdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 62.9 MB/s eta 0:00:00
# ...

# %%
# Install:
# pip install pymupdf

import fitz

pdf = fitz.open("/content/Adarsh_DS.pdf.pdf")

print("Total pages:", len(pdf))

for page_number, page in enumerate(pdf, start=1):

    text = page.get_text()

    print(f"\n--- Page {page_number} ---")
    print(text)

pdf.close()
# Out:
# ...
# Total pages: 2
#
# --- Page 1 ---
# Education
#
# Skills
#
# Experience
# DataScientist | AIML Labs Pvt Ltd from 2024 Jan to Present
# G ADARSH KUMAR REDDY
# DataScientist | 2.7 YearsExperience | ML | Generative AI | Agent AI | NLP
# gadarshkumarreddy2001@gmail.com
# 8688637288
# ComputerEngineering (AI AND ML), Presidency University, Bangalore
#  Bangalore, India
# Programming: Python,SQL
# Machine Learning & AI: Scikit-learn, TensorFlow, Keras, PyTorch, XGBoost, LightGBM, OpenAI API, LangChain
# Statistics & Probability: Descriptive statistics,Hypothesis testing, Probability distributions
# Generative & Agent AI: Transformers, GPT models, Conversational AI, Reinforcement Learning, RAG
# NLP Tools: NLTK, spaCy, TextBlob, Transformers
# Data Processing & Analysis: Pandas, NumPy, SciPy, Feature Engineering, SMOTE
# Data Visualization: Matplotlib, Seaborn, Plotly
# Databases: MySQL, PostgreSQL, MongoDB
# Tools: Jupyter Notebook, VS Code, Git, Docker
# Other Skills: API Integration
# ...

# %%
### for all advanced work use either fitz or pdfplumber
### if it is computer genrated text all three should generate similar accuracy

# %%
from pypdf import PdfReader

reader = PdfReader("/content/Adarsh_DS.pdf.pdf")

pdf_text = ""

for page in reader.pages:

    text = page.extract_text()

    if text:
        pdf_text += text + "\n"

print(pdf_text)
# Out:
# E d u c a t i o n
#
# S k i l l s
#
# E x p e r i e n c e
# D a t a S c i e n t i s t  |  A I M L  L a b s  P v t  L t d  f r o m  2 0 2 4  J a n  t o  P r e s e n t
# G  A D A R S H  K U M A R  R E D D Y
# D a t a S c i e n t i s t  |  2 . 7  Y e a r s E x p e r i e n c e  |  M L  |  G e n e r a t i v e  A I  |  A g e n t  A I  |  N L P
# g a d a r s h k u m a r r e d d y 2 0 0 1 @ g m a i l . c o m 8 6 8 8 6 3 7 2 8 8
# C o m p u t e r E n g i n e e r i n g  ( A I  A N D  M L ) ,  P r e s i d e n c y  U n i v e r s i t y ,  B a n g a l o r e
#  B a n g a l o r e ,  I n d i a
# P r o g r a m m i n g :  P y t h o n , S Q L
# M a c h i n e  L e a r n i n g  &  A I :  S c i k i t - l e a r n ,  T e n s o r F l o w ,  K e r a s ,  P y T o r c h ,  X G B o o s t ,  L i g h t G B M ,  O p e n A I  A P I ,  L a n g C h a i n
# ...

# %%
chunk_size = 500

chunks = []

for i in range(0, len(pdf_text), chunk_size):
    chunk = pdf_text[i:i + chunk_size]
    chunks.append(chunk)

print("Total chunks:", len(chunks))

print(chunks[0])
# Out:
# Total chunks: 24
# E d u c a t i o n
#
# S k i l l s
#
# E x p e r i e n c e
# D a t a S c i e n t i s t  |  A I M L  L a b s  P v t  L t d  f r o m  2 0 2 4  J a n  t o  P r e s e n t
# G  A D A R S H  K U M A R  R E D D Y
# D a t a S c i e n t i s t  |  2 . 7  Y e a r s E x p e r i e n c e  |  M L  |  G e n e r a t i v e  A I  |  A g e n t  A I  |  N L P
# g a d a r s h k u m a r r e d d y 2 0 0 1 @ g m a i l . c o m 8 6 8 8 6 3 7 2 8 8
# C o m p u t e r E n g i n e e r i n g  ( A I  A N D  M L ) ,  P r e s i d e n c y  U n

# %%
import os
for i in glob.glob("/content/*.docx"):
  os.remove(i)

# %%
import json

with open("sample.json", "r", encoding="utf-8") as file:
    data = json.load(file)

print(data)
# Out:
# {'students': [{'id': 101, 'name': 'Anil', 'course': 'Python', 'score': 88}, {'id': 102, 'name': 'Priya', 'course': 'Data Engineering', 'score': 92}, {'id': 103, 'name': 'Rahul', 'course': 'DevOps', 'score': 85}]}

# %%
{

}

# %%
data['students'][1]['course']
# Out:
# 'Data Engineering'

# %%
# !pip install docx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for docx: filename=docx-0.2.4-py3-none-any.whl size=53893 sha256=e65e02efb6f8b1559e7ca8a20e23a736863efa79872c641b56000f1cdf076717
#   Stored in directory: /root/.cache/pip/wheels/f3/ba/dd/43ed5f165600f41deddeb1e382c56ffc1067c09ec5bd705f39
# Successfully built docx
# ...

# %%
pip install exceptions
# Out:
# ERROR: Could not find a version that satisfies the requirement exceptions (from versions: none)
# ERROR: No matching distribution found for exceptions

# %%
# !pip install python-docx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 5.6 MB/s eta 0:00:00
# ...

# %%
# pip install python-docx

from docx import Document

document = Document("/content/37_Harsha_Vardhan.docx")

text = ""

for paragraph in document.paragraphs:
    text += paragraph.text + "\n"

print(text)
# Out:
# Harsha Vardhan
# AI / Machine Learning Engineer
# Email: harsha.vardhan@email.com   |   Phone: +91-9XXXXXXXXX   |   Location: India   |   Pass Out Year: 2026
# CAREER OBJECTIVE
# Aspiring Data Scientist / AI Engineer with a strong foundation in machine learning, deep learning, and generative AI, seeking to apply analytical and problem-solving skills to deliver impactful, data-driven solutions across retail, banking, and pharma domains.
# ROLES & RESPONSIBILITIES
# Design, develop, and validate machine learning and AI models to solve real-world business problems across retail, banking, and pharma domains.
# Perform data collection, cleaning, and feature engineering to prepare high-quality datasets for model training and evaluation.
# Build and deploy GenAI applications including RAG pipelines, chatbots, and document summarization tools using LangChain and Azure OpenAI.
# ...

# %%
import xml.etree.ElementTree as ET

tree = ET.parse("sample.xml")

root = tree.getroot()

for element in root:
    print(element.tag, element.text)
# Out:
# student None
# student None

# %%
for i in root.findall("student"):
  print(i.get("id"))
  print(i.find("name").text)
  print(i.find("course").text)
  print(i.find("score").text)
  print(" ")
# Out:
# 101
# Anil
# Python
# 88
#
# 102
# Priya
# Data Engineering
# 92

# %%
# pip install beautifulsoup4

from bs4 import BeautifulSoup

with open("sample.html", "r", encoding="utf-8") as file:
    soup = BeautifulSoup(file, "html.parser")

text = soup.get_text()

print(text)
# Out:
# Edukron TrainingSample HTML file.
# PythonData EngineeringDevOpsGenAI

# %%
# pip install pyyaml

import yaml

with open("sample.yaml", "r") as file:
    data = yaml.safe_load(file)

print(data)
# Out:
# {'training': {'organization': 'Edukron', 'courses': ['Python', 'Data Engineering', 'DevOps', 'Generative AI'], 'active': True}}

# %%
data
# Out:
# {'training': {'organization': 'Edukron',
#   'courses': ['Python', 'Data Engineering', 'DevOps', 'Generative AI'],
#   'active': True}}

# %%
import pandas as pd

df = pd.read_parquet("data.parquet")

print(df)

# %%
id,name,department,salary
101,Anil,IT,50000
102,Priya,HR,60000
103,Rahul,IT,75000

# %%
id:,101,102,103

name:
Anil
Priya
Rahul

department:
IT
HR
IT

salary:
50000
60000
75000

# %%
columnar storage

# %%
import pickle

with open("data.pkl", "rb") as file:
    data = pickle.load(file)

print(data)

# %%
with open("sample.log", "r", encoding="utf-8") as file:
    logs = file.readlines()

for log in logs:
    print(log.strip())
# Out:
# 2026-08-18 09:00:01 INFO Application started
# 2026-08-18 09:00:05 INFO Database connection successful
# 2026-08-18 09:01:10 WARNING Memory usage reached 75%
# 2026-08-18 09:02:20 ERROR Failed request REQ1001

# %%
logs
# Out:
# ['2026-08-18 09:00:01 INFO Application started\n',
#  '2026-08-18 09:00:05 INFO Database connection successful\n',
#  '2026-08-18 09:01:10 WARNING Memory usage reached 75%\n',
#  '2026-08-18 09:02:20 ERROR Failed request REQ1001\n']

# %%
import zipfile

with zipfile.ZipFile("sample.zip", "r") as zip_file:

    print(zip_file.namelist())

    for i in zip_file.namelist():
      print(i)
# Out:
# ['sample.txt', 'sample.csv', 'sample.json']
# sample.txt
# sample.csv
# sample.json
