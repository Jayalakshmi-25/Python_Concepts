# %%
try
except
else
finally

# %%
pre defined exceptions

# %%
typeerror
zerodivisionerror
indexerror
keyerror
filenotfound
valueerror

# %%
### Custom exceptions
  ### raise

# %%
age=-5
if age<0:
  print("age should not be less than zero")
# Out:
# age should not be less than zero

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2471/376106396.py in <cell line: 0>()
# ----> 1 2+"data"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
loanamount=int(input())
if loanamount>100000:
  raise ValueError("loan amount shoudl never exceed 1 lakh rupees")
else:
  print("loan amount is within limit")
# Out:
# 1000000000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2471/659439405.py in <cell line: 0>()
#       1 loanamount=int(input())
#       2 if loanamount>100000:
# ----> 3   raise ValueError("loan amount shoudl never exceed 1 lakh rupees")
#       4 else:
#       5   print("loan amount is within limit")
#
# ValueError: loan amount shoudl never exceed 1 lakh rupees

# %%
int("age")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2471/856578602.py in <cell line: 0>()
# ----> 1 int("age")
#
# ValueError: invalid literal for int() with base 10: 'age'

# %%
record_count = 0

try:
    # if record_count <= 0:
    #     raise ValueError("Record count must be greater than zero")
    int("data")
    print("Processing records...")

except ValueError as e:  ## alias name
    print("Pipeline Error:", e)
# Out:
# Pipeline Error: invalid literal for int() with base 10: 'data'

# %%
int("data")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2471/4169481474.py in <cell line: 0>()
# ----> 1 int("data")
#
# ValueError: invalid literal for int() with base 10: 'data'

# %%
accuracy = 1.5

try:
    if accuracy < 0 or accuracy > 1:
        raise ValueError("Accuracy must be between 0 and 1")

    print("Model Accuracy:", accuracy)

except ValueError as e:
    print("Model Error:", e)
# Out:
# Model Error: Accuracy must be between 0 and 1

# %%
rasie command using existing exceptions

# %%
class InsufficientBalanceError(Exception):
    pass


balance = 5000
withdraw = 8000

try:
    if withdraw > balance:
        raise InsufficientBalanceError(
            "Withdrawal amount exceeds balance"
        )

    balance -= withdraw
    print("Remaining Balance:", balance)

except InsufficientBalanceError as e:
    print("Bank Error:", e)
# Out:
# Bank Error: Withdrawal amount exceeds balance

# %%
###
